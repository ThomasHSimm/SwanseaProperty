# %% [markdown]
# # Creating data for clustering

# %% [markdown]
# Section which includes: “food, drinks, coffee, shops, arts, outdoors, sights, trending, nextVenues (venues frequently visited after a given venue), or topPicks (a mix of recommendations generated without a query from the user)”

# %%
from ClusteringByLocation import fit_Clusters, Clustering

# %%
fname='Cluster_800_50_outdoors'
cattype=fname.split('_')[-1]
print(fname,cattype)
# Out:
# Cluster_800_50_outdoors outdoors

# %%
swansea_grouped, swansea_venues=Clustering(fname,800,50,cattype)
# Out:
# using-- LIMIT= 50 , radius=  800 ,  section=  sights
# W00002269
# Could take a while press any key to continue
#
# W00002270
# W00002271
# W00002327
# W00002328
# W00002329
# W00002332
# W00002684
# W00002685
# W00002686
# W00002687
# W00002688
# W00002689
# W00002690
# W00002691
# W00002695
# W00002696
# W00002697
# W00002698
# W00002699
# W00002700
# W00002701
# W00002702
# W00002703
# W00003960
# W00003961
# W00003962
# W00003963
# W00003964
# W00003965
# W00003966
# W00003967
# W00003968
# W00003969
# W00003970
# W00003971
# W00003972
# W00003973
# W00003974
# W00003975
# W00003976
# W00003977
# W00003978
# W00003980
# W00003981
# W00003982
# W00003983
# W00003984
# W00003986
# W00003987
# W00003988
# W00003989
# W00003990
# W00003991
# W00003992
# W00003993
# W00003995
# W00003996
# W00003997
# W00003998
# W00003999
# W00004001
# W00004002
# W00004003
# W00004004
# W00004005
# W00004006
# W00004007
# W00004008
# W00004009
# W00004010
# W00004011
# W00004012
# W00004013
# ...

# %%
m=fit_Clusters(fname)
# Out:
# Enter K value (integer)- look for Elbow
# 60
# Using k as --> 60
# got here

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
from ClusteringByLocation import ClusterPlotFunction
fname_Fol=fname+'_Fol_.pkl'
m=ClusterPlotFunction(fname_Fol)
# Out:
# got here

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
